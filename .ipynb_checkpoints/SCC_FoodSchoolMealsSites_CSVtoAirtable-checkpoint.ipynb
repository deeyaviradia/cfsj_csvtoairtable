# %%
#Functions for parsing columns of the spreadsheet on Santa Clara County School Meals
import re
abbrev_to_index = {
    'm': 0, 'mon': 0, 'monday': 0, 'mondays': 0,
    't': 1, 'tues': 1, 'tuesday': 1, 'tuesdays': 1,
    'w': 2, 'wed': 2, 'wednesday': 2, 'wednesdays': 2,
    'th': 3, 'thr': 3, 'thurs': 3, 'thursday': 3, 'thursdays': 3,
    'f': 4, 'fri': 4, 'friday': 4, 'fridays': 4,
    's': 5, 'sat': 5, 'saturday': 5, 'saturdays': 5,
    'su': 6, 'sun': 6, 'sunday': 6, 'sundays': 6
}

daysOfWeek = {
    '0': 'Monday',
    '1': 'Tuesday',
    '2': 'Wednesday',
    '3': 'Thursday',
    '4': 'Friday',
    '5': 'Saturday',
    '6': 'Sunday',

}
 
def fcnparse_siteaddress(csvaddress):
    myoutput = nominatim.query(csvaddress+ ' California')
    if len(myoutput.toJSON())>0:
        myjson = myoutput.toJSON()[0]
    
        #print(myjson)
        #print(type(myjson))
        full_address = myjson['display_name']
        #print(full_address)
        #print(type(full_address))

        tmp = full_address.split(', ')
        #print(tmp)
       
        if tmp[0].isnumeric():
            address = tmp[0]+" "+tmp[1]
            city = tmp[-5:-4][0]
            state = tmp[-3:-2][0]
            zipcode = tmp[-2:-1][0]            
        elif tmp[1].isnumeric():
            address = tmp[1]+" "+tmp[2]
            city = tmp[-5:-4][0]
            state = tmp[-3:-2][0]
            zipcode = tmp[-2:-1][0]
        else:
            address = csvaddress+" ######CHECK ME######"
            city = "######CHECK ME######"
            zipcode = "######CHECK ME######"
            state = "California"
    else:
        full_address = ""
        address = csvaddress+"######CHECK ME######"
        city = "######CHECK ME######"
        zipcode = "######CHECK ME######"
        state = "California"
        
    return full_address, address, city, state, zipcode

def fcnparse_opendays_opentime(dh_str):
    dh_str = str(dh_str)
    try:
        days = dh_str.split("@")[0].split("\n")[0].lower()
        found = re.search('(through|-|to)', days)
        if not found:
            day = []
            # search for each day in the days
            for d in abbrev_to_index.keys():
                if len(d) > 1:
                    found = re.search(d, days)
                    if found:
                        day.append(d) 

            days = ",".join(day)
        else:
            days = days.replace("through", "-").replace("'s", "").replace("and", ",").replace(' ', '')
        timing = dh_str.split("@")[1]

        dh_str = days + "," + timing
    except:
        dh_str = ""

    day_cols = [''] * 7
    open_day_time = [''] * 3
    if not isinstance(dh_str, str):
        return day_cols

    dh_str = dh_str.strip()

    if 'call' in dh_str:
        return ['call number'] * 7

    openTime = ""
    for dh in dh_str.split(';'):
        dh = dh.strip()
        dh = re.sub('\.', '', dh)  # Remove periods

        # Parse hours
        hours = re.search('\\d.*[pam]*', dh)
        if not hours:
            return ('','', '')
        else:

            hours_str = dh[hours.start():hours.end()].replace("to", "-").replace("â€“", "-")  # Extract hours
            dh = dh[:hours.start()] + dh[hours.end():]  # And remove from dh

        # Assign hours to the correct day(s)
        days = re.split('[,&|]', dh)
        for day in days:
            day = day.strip()
            if len(day) == 0:  # Empty day
                continue
            elif '-' in day:  # Day range (ex. M-F)
                day_range = day.split('-')
                if len(day_range) == 2 and day_range[0] in abbrev_to_index and day_range[1] in abbrev_to_index:
                    start_index = abbrev_to_index[day_range[0]]
                    end_index = abbrev_to_index[day_range[1]]
                    for i in range(start_index, end_index + 1):
                        day_cols[i] = hours_str
            elif day in abbrev_to_index:  # Single day
                index = abbrev_to_index[day]
                day_cols[index] = hours_str

        timing = ""
        for i in range(0, len(day_cols) - 1):
            if day_cols[i]:
                timing = day_cols[i]
                day_cols[i] = daysOfWeek[str(i)]

        if openTime == "":
            # Start Time
            openTime = str(timing.split("-")[0]).strip()

            # End Time
            closeTime = ""
            try:
                closeTime = str(timing.split("-")[1]).strip()
            except:
                pass

    day_cols = list(set(day_cols))
    if "" in day_cols:
        day_cols.remove("")


    return (",".join(day_cols), openTime, closeTime)

def fcnparse_mealtypes(attributesMEALTYPES):
    #print(attributesMEALTYPES)
    mealoptions = []
    if re.search('breakfast', attributesMEALTYPES, re.IGNORECASE):
        mealoptions = mealoptions + ["Breakfast", ]
    if re.search('lunch', attributesMEALTYPES, re.IGNORECASE):
        mealoptions = mealoptions + ["Lunch", ]  
    if re.search('dinner', attributesMEALTYPES, re.IGNORECASE):
        mealoptions = mealoptions + ["Dinner", ]   

    #print(mealoptions)
    return mealoptions

# %%
import urllib

def getOrCreateAirTable(_url, _header, _data, _uniqueFieldName):
    _f ={
        "maxRecords": 1,
        "filterByFormula": "{"+_uniqueFieldName+"}='"+_data["fields"][_uniqueFieldName]+"'"
    }
    _filter = "?"+urllib.parse.urlencode(_f)
    _res = requests.get(_url+_filter, headers = _header)
    _recs = json.loads(_res.text.encode('utf8'))["records"]
    if len(_recs) == 0:
        return insertIntoAirTable(_url, _header, _data)
    else:
        _id = json.loads(_res.text.encode('utf8'))["records"][0]["id"]
        print("Existing Id -> "+str(_id) + "::: "+ _url)
        return _id
    
    
def insertIntoAirTable(_url, _header, _data):
#     print("Insered Data -> {0}".format(_data))
#     print ("."*40)
    _res = requests.post(_url, headers = _header, data = json.dumps(_data))
#     print(_res.text)
    _id = json.loads(_res.text.encode('utf8'))["id"]
#     print("Id -> "+str(_id) + "::: "+ _url)
#     print("Response     -> {0}".format(_res.text))
    print("-"*80)
    return _id

def updateServicesAirTable(_url, _header, _data):
    _res = requests.patch(_url, headers = _header, data = json.dumps(_data))
    #print("Update Services "+ " ::: "+ _url)
    #print(_res.text)
    #print("-"*80)

# %%
#Code to scrape Santa Clara County school meal sites
import requests
import csv
import json
import time
#from OSMPythonTools.nominatim import Nominatim
#nominatim = Nominatim()

post_url_services = 'https://api.airtable.com/v0/appr1xuf08nFiiLTF/services'
post_url_organizations = 'https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations'
post_url_address = 'https://api.airtable.com/v0/appr1xuf08nFiiLTF/address'
post_url_location = 'https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations'
post_url_schedule = 'https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule'
post_url_phones = 'https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones'

post_headers = {
    'Authorization' : 'Bearer keyLBTgL8hjaceVN4',
    'Content-Type': 'application/json'
}
csvfilename = open('c:\deeya\Santa Clara Scrape Food School Meal Sites .csv', encoding='utf-8')
csv_f = csv.reader(csvfilename)

#Skip header row
count = 1
for row in csv_f:
    if count == 1:
        break

#Loop over all rows and parse out the columns in each row
count = 1
for row in csv_f:
#     # skip till you find the Service to start at...
#     if row[5] != "Lakeside School":
#         continue
        
        
    rowcount = 0
    for elem in row:
        rowcount = rowcount+1
    #################################################
    #Upload to Service Table
    #################################################
    #Parse data for SERVICES sheet: attributes.SITENAME, attributes.MEALTYPES, 
    #attributes.SITESTATUS, attributes.DESCRIPTION, attributes.EMAIL, attributes.WEBLINK
    attributesSITENAME = row[5]
    attributesMEALTYPES = fcnparse_mealtypes(row[10])
    attributesSITESTATUS = row[12]
    attributesDESCRIPTION = row[13]+" "+row[23]    
    attributesEMAIL = row[15]
    attributesWEBLINK = row[16]
    airtableSERVICES = {
        "fields": {
            "Name": attributesSITENAME, 
            "active": attributesSITESTATUS,
            "Description": attributesDESCRIPTION,
            "email": attributesEMAIL,
            "url": attributesWEBLINK
        }
    }
    print("Upload to service table -> " + attributesSITENAME )
    serviceId = getOrCreateAirTable(post_url_services, post_headers, airtableSERVICES, "Name")
    
    ##################################################
    #Upload to Organization Table
    ##################################################
    attributesSITESCHOOLDISTRICT = row[4]
    airtableORGANIZATIONS = {
        "fields": {
            "name": attributesSITESCHOOLDISTRICT, 
            "description": "", "phones": []
        }
    }
    print("Upload to organization table")
    organizationId = getOrCreateAirTable(post_url_organizations, post_headers, airtableORGANIZATIONS, "name")
    
    ###################################################
    #Upload to Address Table
    ###################################################
    #Parse data for ADDRESS sheet: attributes.SITEADDRESS   
    attributesSITEADDRESS = row[6]
    #print(attributesSITEADDRESS)
    #full_address, address, city, state, zipcode = fcnparse_siteaddress(attributesSITEADDRESS)
    #print(full_address)
    #print(count+1, address, city, state, zipcode, '\n')
    address = "1234 Memory Lane"
    city = "San Jose"
    state = "CA"
    zipcode = "95124"
    airtableADDRESS = {
        "fields": {
            "address_1": address,
            "city": city,
            "State": state,
            "Zip Code": zipcode
        }
    }
    print("Upload to address table")
    addressId = getOrCreateAirTable(post_url_address, post_headers, airtableADDRESS, "address_1")
    
    ####################################################
    # Upload to Phone Table
    ####################################################
    # Parse data for PHONES sheet: attributes.PHONENUMBER
    attributesPHONENUMBER = row[14] if row[14] != '' else "n/a"
    airtablePHONES = {"fields": {"number": attributesPHONENUMBER, "services" : [serviceId], "organizations" : [organizationId] }}
    print("Upload to phone table")
    phoneId = getOrCreateAirTable(post_url_phones, post_headers, airtablePHONES, "number")
    
    ##################################################
    #Upload to Schedule Table
    ##################################################
    #Parse data for SCHEDULE sheet: attributes.OPENDAYS, attributes.OPENTIMES
    attributesOPENDAYS = row[7]
    attributesOPENTIMES = row[8]
    opendaystime = fcnparse_opendays_opentime(attributesOPENDAYS+ '@'+ attributesOPENTIMES)
    airtableSCHEDULE = {
        "fields": { 
            "name": attributesSITESCHOOLDISTRICT,
            "services": [serviceId], 
            "weekday": opendaystime[0].split(","), 
            "opens_at": opendaystime[1], 
            "closes_at": opendaystime[2]  
        }
    } 
    
    if airtableSCHEDULE["fields"]["weekday"] == ['']:
        airtableSCHEDULE["fields"]["description-x"]  = "####### Please check data ######" 
        airtableSCHEDULE["fields"]["weekday"] = []

    print("Upload to schedule table")
    scheduleId = getOrCreateAirTable(post_url_schedule, post_headers, airtableSCHEDULE, "name")
   
    ###################################################
    #Upload to Location Table
    ###################################################
    airtableLOCATION = {
                          "fields": {
                            "name": row[6],
                            "latitude": row[24],
                            "longitude": row[25],
                            "services": [
                              serviceId
                            ],
                            "schedule": [
                              scheduleId
                            ],
                            "address": [
                              addressId
                            ]
                          }
                        }
    print("Upload to location table")
    LocationId = getOrCreateAirTable(post_url_location, post_headers, airtableLOCATION, "name")
    
    
    ####################################################
    # Update Services Table
    ####################################################
    
    airtableSERVICES = {
                          "fields": {
                            "Organization": [
                              organizationId
                            ],
                            "phones": [
                              phoneId
                            ],
                            "schedule":[
                              scheduleId
                            ],
                            "locations":[
                                LocationId
                            ]
                          }
                        }
    updateServicesAirTable("https://api.airtable.com/v0/appr1xuf08nFiiLTF/services/"+serviceId, post_headers, airtableSERVICES)
    
    
    count = count + 1
    if count == -1:
        break
# Out:
# Upload to service table -> Painter/Sheppard MS
# Existing Id -> recbyhm5IGIjmsnVg::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recXvK0QNvX8BVeZH::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recvgrzpmY9vbbaIh::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recsD677d121IKqGW::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Hubbard Elementary
# Existing Id -> recFfTKKAFZJWWD7c::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recXvK0QNvX8BVeZH::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recvgrzpmY9vbbaIh::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recnH8i39PW5KFpvi::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Dorsa Elementary
# Existing Id -> recbWAzCkgbYhbvWl::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recXvK0QNvX8BVeZH::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recvgrzpmY9vbbaIh::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recN5u8Gjm57bRhLy::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Cesar Chavez School
# Existing Id -> recFYwpjoYhPuHEuM::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recXvK0QNvX8BVeZH::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recvgrzpmY9vbbaIh::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recP6nkvfsVFZ2ZkZ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Arbuckle Elementary
# Existing Id -> recbfbVLv1nhqRXk7::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recXvK0QNvX8BVeZH::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recvgrzpmY9vbbaIh::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recoovxyWLZSWtajR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Linda Vista Elementary
# Existing Id -> recHwKUHrqstwlsGC::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recXvK0QNvX8BVeZH::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recvgrzpmY9vbbaIh::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rechn0SDRX4JfGcPE::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Piedmont Middle School
# Existing Id -> recUPjuQOVGnVnW0k::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reco5fXj85YmXsmaJ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recWPqqRbEdEHFpEA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recdVLstb5Nmj7cTc::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Morrill Midde School
# Existing Id -> rec802f7jnFDSR3Vv::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reco5fXj85YmXsmaJ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recWPqqRbEdEHFpEA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rec42YCiWskWmpq4g::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Vinci Park Elementary
# Existing Id -> rece1hyDhQ7srgEvQ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reco5fXj85YmXsmaJ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recWPqqRbEdEHFpEA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recsfvtR8XEdF1t0I::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Price Middle School
# Existing Id -> rectoHcgdXNLk79am::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recj1bGShioY7NETm::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recKpWQZJ9yxpW3RZ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> reckCUJo0JFfhHfXM::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Blackford Elementary
# Existing Id -> recVOlDj8gK6ERLFm::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recETpasfMsyxtZZA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recuDXSgcZxfGAQAT::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rec8tsjGdjuo9UfRH::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Capri Elementary
# Existing Id -> recxVjng5BjDSIQJi::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recETpasfMsyxtZZA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recuDXSgcZxfGAQAT::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> receu474RVnARqZvU::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Castlemont Elementary
# Existing Id -> recbfj2YgS0NVkAqq::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recETpasfMsyxtZZA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recuDXSgcZxfGAQAT::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recd41jWjBIMLGDgD::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Lynhaven Elementary
# Existing Id -> recC3J2thZgaV4mSN::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recETpasfMsyxtZZA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recuDXSgcZxfGAQAT::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recK6oQUsdr1X8gzL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Rosemary Elementary
# Existing Id -> receHgOj0rmBXMWds::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recETpasfMsyxtZZA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recuDXSgcZxfGAQAT::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rec9g5lLiaT6zgmh9::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Sherman Oaks Elementary
# Existing Id -> rec4cCXJ5sa0a0hHj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recETpasfMsyxtZZA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recuDXSgcZxfGAQAT::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recOMPgryq4hm2zGe::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Monroe Middle
# Existing Id -> recwjQkuaL0eD7a5k::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recETpasfMsyxtZZA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recuDXSgcZxfGAQAT::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recS42xsfcquG9FBJ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Boynton High
# Existing Id -> recnCpL2R9tSl8KYq::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recKyJG1sCof5xpLN::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec5sJ7G3lLh5LsjZ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recF6LKbI4qKOghVQ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Branham High
# Existing Id -> rec0l9DsrK1KYYgKG::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recKyJG1sCof5xpLN::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec5sJ7G3lLh5LsjZ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recFNw3qG7XBs0Oey::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Del Mar High
# Existing Id -> rec2nHpc8Ij2ghZ5H::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recKyJG1sCof5xpLN::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec5sJ7G3lLh5LsjZ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recu9buMVqHNv8bZP::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Leigh High
# Existing Id -> recDH5i0A6LEfweRY::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recKyJG1sCof5xpLN::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec5sJ7G3lLh5LsjZ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recrOAWRTsz2kIIWG::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Prospect High
# Existing Id -> recpbLwFq461zrljI::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recKyJG1sCof5xpLN::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec5sJ7G3lLh5LsjZ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recw0MtjlCMQfWLXQ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Westmont High
# Existing Id -> rec4ny0cJ3AKMEWfx::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recKyJG1sCof5xpLN::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec5sJ7G3lLh5LsjZ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recm41If1MX1gEXof::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Cupertino Middle School
# Existing Id -> recTzxJUnnt7Vb9wP::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recpPvj0mgzKBwkfO::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> recw5ZblgSqpRfG6Y::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rectmlXWKepELRQu6::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Foothill High School
# Existing Id -> rec0xDF0LjxtNJXWl::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recA7fcVsJaO8doLA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Andrew Hill HS
# Existing Id -> recgmccZmRiEVnwfL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rec7Ag8Ko67Uekm5I::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Calero High School
# Existing Id -> reczggTbTQZhjKngJ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recTNcwMrMWAdZR8t::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Evergreen High School
# Existing Id -> recRuQsHp4eRgx6vb::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recaJOSgnBxGm5Eo1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Independence HS
# Existing Id -> recRc0m5HkKVQTbJq::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recFcZIN2uL9LeJrd::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> James Lick HS
# Existing Id -> recf89xlYllF14fJX::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recUMVQkgRIsPVkn6::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Mt. Pleasant HS
# Existing Id -> rec6YFK1KCu10wmZd::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recO4lgJpmPt7HP37::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Oak Grove High School
# Existing Id -> recvPRhuWsqQtuf6O::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> reccKmL5cidyttJxO::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Piedmont Hills High School
# Existing Id -> recZHiuI7HRwPP67E::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recaSvM5RkHGcFRwM::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Santa Teresa High School
# Existing Id -> rec0OVReZ7viBjC9m::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recOa39phMUFhuZyu::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Silver Creek High School
# Existing Id -> recjCmyvS52BgLKc4::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rec7sC7o3W3a8TsdV::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> WC Overfelt High School
# Existing Id -> recDFkC079tgpNwGI::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recONwhugHGVQxEgm::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Yerba Buena High School
# Existing Id -> recyvoEaAkiyHFN5b::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> recIFVrQYKylF7elj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec7nAYnm9X9u9OS1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recLCd2QTpluKQHdT::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Caldwalder
# Existing Id -> recgJdsE2jjWdNpqR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recyuc4gazSwFurTL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Carolyn Clark
# Existing Id -> rec9xdIvSGkIgWaH6::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recqoQ1uWsoxhP1Ay::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Cedar Grove
# Existing Id -> recZBSB8WvbnBsu8F::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recYuOUg1AZI0QOpO::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Chaboya
# Existing Id -> recmMmOhOsN4uECTa::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recPiuNxRir9Xc7Xu::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Dove Hill
# Existing Id -> recuP0H3XfRt4HauJ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rechDxjpn20HDxT4p::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Evergreen Elementary School
# Existing Id -> recBE5O6sjjAu2RiV::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recOij9zvGKN3Z71B::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Holly Oak Elementary School
# Existing Id -> recoHm1cwPT1DIvuh::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recuHCCy6RHq1OP0U::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Laurelwood
# Existing Id -> recnYTc6jHV55Bx7j::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rec73xNPCEEGKlFho::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Levya
# Existing Id -> recVwQkgLlW580CHl::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> reczMqgkzcKgDcTzl::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Matsumoto
# Existing Id -> recNlmmZYKK4pIjVL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> reczg5rHz6ToCfyzl::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Millbrook
# Existing Id -> recHlpHkF0STobVTr::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recllvboTaFrCvy7S::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Montegomery Elementary School
# Existing Id -> recvdH2LEwoGRSbxl::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recXeVvz4RkJ89ZLI::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Norwood Elementary School
# Existing Id -> recqSTqEQFeNihrY5::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recrCKgTWknrAhIBD::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Quimby
# Existing Id -> recunx85KGDv4wn5U::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recXAhhVzspDJJRf6::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Silver Oak
# Existing Id -> recGswqJgUBKdG14c::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recKr8nYrNFnJMHhL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> J.F. Smith
# Existing Id -> recUoUvdnySPe5UrN::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rec5QtAnitg3rR0Vy::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Katherine Smith Elementary School
# Existing Id -> recR2Hjnijr4jOhWY::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recZseUbKczrJj96J::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> O.B. Whaley Elementary School
# Existing Id -> reckjIHZSHcuUg8yN::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> rec6YJrUnJMkitgO2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rec8w7ZhyLvOim4CL::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recCpMoKHBX49xabA::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Dahl Elementary School
# Existing Id -> recEd4fmpEpxpEX4k::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rechbXkVfgGHbJOUz::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Franklin
# Existing Id -> recfmRGkLmMMH7BVU::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> reccx58YfT4agtM3e::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Hellyer Elementary School
# Existing Id -> recxXklsBZZ0m9x7O::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recVJdamKPHWViLkT::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Kennedy
# Existing Id -> reckmF5ZIM2PHp2SM::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recYqUNUCVuwOjBJv::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Larion Lairon College Preparatory
# Existing Id -> reca8JXEuPK9LRFXI::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recibdHUMUUarev40::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Los Arboles
# Existing Id -> rect6Jd5MogvFdqKI::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recxNncmh4FmwCJUF::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Mckinley
# Existing Id -> recHF0ATic8Rbrhvi::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rechgnAaJvZ54mLsw::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Meadows
# Existing Id -> recTjX4V0445AiIGr::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recd9wGT1CJacTQkc::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Ramblewood
# Existing Id -> recfCj9CkPod6ooMK::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recTZ3pHMKLJl1Lvj::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Santee Elementary School
# Existing Id -> recoGSmJjpWSBIU3J::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recvKbvIikv0BLI3k::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Shirakawa Sr School
# Existing Id -> rec7n5KEUUxT3jKdk::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recLMAfrqaLWwEnlc::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Stonegate School
# Existing Id -> rechysWqKyOUvkwrV::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recMHTphth4bb4apb::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Windmill Springs School
# Existing Id -> recM1BGQGEmT5hmiQ::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> rechG6tFVJsDTytPW::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Bridges
# Existing Id -> recJjqUof4DtPSqQn::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recEfz0sJLm91ajXM::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> College Connection
# Existing Id -> recqbuljIl0O9kBP6::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table
# Existing Id -> reciZwkugJLYszLgt::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/organizations
# Upload to address table
# Existing Id -> recZwmBF0jwWjUvS2::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/address
# Upload to phone table
# Existing Id -> recCUUStHZUoT9XH1::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/phones
# Upload to schedule table
# Existing Id -> rect4bBAwzKFcsvaR::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/schedule
# Upload to location table
# Existing Id -> recvgH6DhWMO9ClkK::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/locations
# Upload to service table -> Sylvandale
# Existing Id -> recNNNm0SRXhKG8UM::: https://api.airtable.com/v0/appr1xuf08nFiiLTF/services
# Upload to organization table

# %%
#Prototyping code for parsing addresses

from OSMPythonTools.nominatim import Nominatim
nominatim = Nominatim()
#myoutput = nominatim.query('1680 Foley ave')
#print(myoutput.toJSON())
csvaddress = '592 Dunholme Way, san jose'
myoutput = nominatim.query(csvaddress)
print(myoutput)
print(myoutput.toJSON())
print(len(myoutput.toJSON()))
myjson = myoutput.toJSON()[0]
print(myjson)
print(type(myjson))
full_address = myjson['display_name']
print(full_address)
print(type(full_address))

tmp = full_address.split(', ')
print(tmp)
firstelem = tmp[0]
print(firstelem)
print(firstelem.isnumeric())
if tmp[0].isnumeric():
    address = tmp[0]+" "+tmp[1]
    city = tmp[-5:-4][0]
    state = tmp[-3:-2][0]
    zipcode = tmp[-2:-1][0]            
elif tmp[1].isnumeric():
    address = tmp[1]+" "+tmp[2]
    city = tmp[-5:-4][0]
    state = tmp[-3:-2][0]
    zipcode = tmp[-2:-1][0]
else:
    address = csvaddress+" ######CHECK ME######"
    city = "######CHECK ME######"
    zipcode = "######CHECK ME######"
    state = "California"

print(address)
print(city)
print(state)
print(zipcode)

# %%
if ~len([]):
    print("yup empty")
# Out:
# yup empty

# %%
#blah = '1680'
#blah.isdigit()
print(1!=2)
# Out:
# True

# %%
#Prototyping code for parsing meal types

import re

if re.search('mandye', 'Mandy Pande', re.IGNORECASE):
    print("Yes found")
    
test_tup1 = [1, 3, 5] 
test_tup2 = [4,]
  
# printing original tuples 
print("The original tuple 1 : " + str(test_tup1)) 
print("The original tuple 2 : " + str(test_tup2)) 
  
# Ways to concatenate tuples 
# using + operator 
res = test_tup1 + test_tup2 
  
# printing result 
print("The tuple after concatenation is : " + str(res))
# Out:
# The original tuple 1 : [1, 3, 5]
# The original tuple 2 : [4]
# The tuple after concatenation is : [1, 3, 5, 4]
